# %%
import json

# %%
with open('./training-data-for-classifier/(iot)-hue_jsons.txt') as json_file:
    data = json.load(json_file)

# %%
with open('./preprocess.txt') as json_file:
    new_data = json.load(json_file)

# %%
data
# Out:
# [{'1': {'state': {'on': False,
#     'bri': 1,
#     'hue': 33761,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.3171, 0.3366],
#     'ct': 159,
#     'alert': 'none',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2018-01-02T19:24:20'},
#    'type': 'Extended color light',
#    'name': 'Hue color lamp 7',
#    'modelid': 'LCT007',
#    'manufacturername': 'Philips',
#    'productname': 'Hue color lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 5000,
#      'maxlumen': 600,
#      'colorgamuttype': 'B',
#      'colorgamut': [[0.675, 0.322], [0.409, 0.518], [0.167, 0.04]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': False}},
#    'config': {'archetype': 'sultanbulb',
#     'function': 'mixed',
#     'direction': 'omnidirectional'},
#    'uniqueid': '00:17:88:01:00:bd:c7:b9-0b',
#    'swversion': '5.105.0.21169'}},
#  {'7': {'name': 'Hue Lamp 7'},
#   '8': {'name': 'Hue Lamp 8'},
#   'lastscan': '2012-10-29T12:00:00'},
#  {'success': {'/lights': 'Searching for new devices'}},
#  {'state': {'hue': 50000,
#    'on': True,
#    'effect': 'none',
#    'alert': 'none',
#    'bri': 200,
#    'sat': 200,
#    'ct': 500,
#    'xy': [0.5, 0.5],
#    'reachable': True,
#    'colormode': 'hs'},
#   'type': 'Living Colors',
#   'name': 'LC 1',
#   'modelid': 'LC0015',
#   'swversion': '1.0.3'},
#  {'hue': 50000, 'on': True, 'bri': 200},
#  {'1': {'name': 'Group 1',
#    'lights': ['1', '2'],
#    'type': 'LightGroup',
#    'action': {'on': True,
#     'bri': 254,
#     'hue': 10000,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.5, 0.5],
#     'ct': 250,
#     'alert': 'select',
#     'colormode': 'ct'}},
#   '2': {'name': 'Group 2',
#    'lights': ['3', '4', '5'],
#    'type': 'LightGroup',
#    'action': {'on': True,
#     'bri': 153,
#     'hue': 4345,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.5, 0.5],
#     'ct': 250,
#     'alert': 'select',
#     'colormode': 'ct'}}},
#  {'lights': ['1', '2'], 'name': 'bedroom', 'type': 'LightGroup'},
#  {'action': {'on': True,
#    'hue': 0,
#    'effect': 'none',
#    'bri': 100,
#    'sat': 100,
#    'ct': 500,
#    'xy': [0.5, 0.5]},
#   'lights': ['1', '2'],
#   'state': {'any_on': True, 'all_on': True},
#   'type': 'Room',
#   'class': 'Bedroom',
#   'name': 'Master bedroom'},
#  {'on': True, 'hue': 2000, 'effect': 'colorloop'},
#  {'1': {'name': 'Timer',
#    'description': '',
#    'command': {'address': '/api/s95jtYH8HUVWNkCO/groups/0/action',
#     'body': {'scene': '02b12e930-off-0'},
#     'method': 'PUT'},
#    'time': 'PT00:01:00',
#    'created': '2014-06-23T13:39:16',
#    'status': 'disabled',
#    'autodelete': False,
#    'starttime': '2014-06-23T13:39:16'},
#   '2': {'name': 'Alarm',
#    'description': '',
#    'command': {'address': '/api/s95jtYH8HUVWNkCO/groups/0/action',
#     'body': {'scene': '02b12e930-off-0'},
#     'method': 'PUT'},
#    'localtime': '2014-06-23T19:52:00',
#    'time': '2014-06-23T13:52:00',
#    'created': '2014-06-23T13:38:57',
#    'status': 'disabled',
#    'autodelete': False}},
#  {'name': 'Wake up',
#   'description': 'My wake up alarm',
#   'command': {'address': '/api/<username>/groups/1/action',
#    'method': 'PUT',
#    'body': {'on': True}},
#   'time': 'W124/T06:00:00'},
#  {'lights': ['3', '2', '5'],
#   'recycle': True,
#   'name': 'My Scene',
#   'appdata': {'data': 'My App Data', 'version': 1},
#   'picture': 'ABC123DEF456'},
#  {'4e1c6b20e-on-0': {'name': 'Kathy on 1449133269486',
#    'lights': ['2', '3'],
#    'owner': 'ffffffffe0341b1b376a2389376a2389',
#    'recycle': True,
#    'locked': False,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2015-12-03T08:57:13',
#    'version': 1},
#   '3T2SvsxvwteNNys': {'name': 'Cozy dinner',
#    'lights': ['1', '2'],
#    'owner': 'ffffffffe0341b1b376a2389376a2389',
#    'recycle': True,
#    'locked': False,
#    'appdata': {'version': 1, 'data': 'myAppData'},
#    'picture': '',
#    'lastupdated': '2015-12-03T10:09:22',
#    'version': 2}},
#  {'name': 'Cozy dinner',
#   'lights': ['1'],
#   'owner': 'newdeveloper',
#   'recycle': True,
#   'locked': False,
#   'appdata': {},
#   'picture': '',
#   'lastupdated': '2015-12-03T10:09:22',
#   'version': 2,
#   'lightstates': {'1': {'on': True, 'bri': 237, 'xy': [0.5806, 0.3903]}}},
#  {'1': {'state': {'daylight': False, 'lastupdated': '2014-06-27T07:38:51'},
#    'config': {'on': True,
#     'long': 'none',
#     'lat': 'none',
#     'sunriseoffset': 50,
#     'sunsetoffset': 50},
#    'name': 'Daylight',
#    'type': 'Daylight',
#    'modelid': 'PHDL00',
#    'manufacturername': 'Philips',
#    'swversion': '1.0'},
#   '2': {'state': {'buttonevent': 0, 'lastupdated': 'none'},
#    'config': {'on': True},
#    'name': 'Tap Switch 2',
#    'type': 'ZGPSwitch',
#    'modelid': 'ZGPSWITCH',
#    'manufacturername': 'Philips',
#    'uniqueid': '00:00:00:00:00:40:03:50-f2'}},
#  {'state': {'buttonevent': 34, 'lastupdated': '2013-03-25T13:32:34'},
#   'name': 'Wall tap 1',
#   'modelid': 'ZGPSWITCH',
#   'uniqueid': '01:23:45:67:89:AB-12',
#   'manufacturername': 'Philips',
#   'swversion': '1.0',
#   'type': 'ZGPSwitch'},
#  {'name': 'Wall Switch Rule',
#   'lasttriggered': '2013-10-17T01:23:20',
#   'creationtime': '2013-10-10T21:11:45',
#   'timestriggered': 27,
#   'owner': '78H56B12BA',
#   'status': 'enabled',
#   'conditions': [{'address': '/sensors/2/state/buttonevent',
#     'operator': 'eq',
#     'value': '16'},
#    {'address': '/sensors/2/state/lastupdated', 'operator': 'dx'}],
#   'actions': [{'address': '/groups/0/action',
#     'method': 'PUT',
#     'body': {'scene': 'S3'}}]},
#  {'lights': {'1': {'state': {'on': False,
#      'bri': 0,
#      'hue': 0,
#      'sat': 0,
#      'xy': [0.0, 0.0],
#      'ct': 0,
#      'alert': 'none',
#      'effect': 'none',
#      'colormode': 'hs',
#      'reachable': True},
#     'type': 'Extended color light',
#     'name': 'Hue Lamp 1',
#     'modelid': 'LCT001',
#     'swversion': '65003148'},
#    '2': {'state': {'on': True,
#      'bri': 254,
#      'hue': 33536,
#      'sat': 144,
#      'xy': [0.346, 0.3568],
#      'ct': 201,
#      'alert': 'none',
#      'effect': 'none',
#      'colormode': 'hs',
#      'reachable': True},
#     'type': 'Extended color light',
#     'name': 'Hue Lamp 2',
#     'modelid': 'LCT001',
#     'swversion': '65003148'}},
#   'groups': {'1': {'action': {'on': True,
#      'bri': 254,
#      'hue': 33536,
#      'sat': 144,
#      'xy': [0.346, 0.3568],
#      'ct': 201,
#      'effect': 'none',
#      'colormode': 'xy'},
#     'lights': ['1', '2'],
#     'name': 'Group 1'}},
#   'config': {'name': 'Philips hue',
#    'mac': '00:00:88:00:bb:ee',
#    'dhcp': True,
#    'ipaddress': '192.168.1.74',
#    'netmask': '255.255.255.0',
#    'gateway': '192.168.1.254',
#    'proxyaddress': '',
#    'proxyport': 0,
#    'UTC': '2012-10-29T12:00:00',
#    'whitelist': {'1028d66426293e821ecfd9ef1a0731df': {'last use date': '2012-10-29T12:00:00',
#      'create date': '2012-10-29T12:00:00',
#      'name': 'test user'}},
#    'swversion': '01003372',
#    'swupdate': {'updatestate': 0, 'url': '', 'text': '', 'notify': False},
#    'linkbutton': False,
#    'portalservices': False},
#   'swupdate2': {'checkforupdate': False,
#    'lastchange': '2017-06-21T19:44:36',
#    'bridge': {'state': 'noupdates', 'lastinstall': '2017-06-21T19:44:18'},
#    'state': 'noupdates',
#    'autoinstall': {'updatetime': 'T14:00:00', 'on': False}},
#   'schedules': {'1': {'name': 'schedule',
#     'description': '',
#     'command': {'address': '/api/<username>/groups/0/action',
#      'body': {'on': True},
#      'method': 'PUT'},
#     'time': '2012-10-29T12:00:00'}}}]

# %%
len(new_data)
# Out:
# 36

# %%
t = 'Hue Lamp 3'
t.lower()
# Out:
# 'hue lamp 3'

# %%
t = ['fdsf', 'fdsaf', {'a': 'fd'}]

# %%
iterate_json(t)
# Out:
# fdsf
# 1
# fdsaf
# 2
# {'a': 'fd'}
# 3
# ['dsafdsf', 'dsafdsaf', {'dsaa': 'dsafd'}]

# %%
def str_process(string):
    return "dsa" + string

# %%
def iterate_json(data):
    if type(data) == list:
        new_list = []
        for item in data:
            if type(item) == list or type(item) == dict:
                print(item)
                new_list.append(iterate_json(item))
            elif type(item) == str:
                print(item)
                new_list.append(str_process(item))
            else:
                new_list.append(item)
            print(len(new_list))
        return new_list
    if type(data) == dict:
        new_dict = {}
        for key, values in data.items():
            if type(key) == str:
                new_key = str_process(key)
            else:
                new_key = key
            if type(values) == list or type(values) == dict:
                new_dict[new_key] = iterate_json(values)
            elif type(values) == str:
                new_dict[new_key] = str_process(values)
            else:
                print("shouldnt")
                new_dict[new_key] = values
        #print(data)
        #print(new_dict)
        #print("------------")
        return new_dict

# %%
new_data = iterate_json(data)
# Out:
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 2
# 2
# 2
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 1
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 2
# 2
# 2
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 3
# 1
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 5
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 3
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 2
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 3
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 6
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 3
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 2
# shouldnt
# shouldnt
# shouldnt
# 4
# shouldnt
# shouldnt
# shouldnt
# 5
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 2
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 10
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 2
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 7
# shouldnt
# shouldnt
# 3
# 2
# 3
# 8
# shouldnt
# 3
# 2
# 3
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# 5
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt
# shouldnt

# %%
new_data
# Out:
# [{'dsa1': {'dsastate': {'dsaon': False,
#     'dsabri': 1,
#     'dsahue': 33761,
#     'dsasat': 254,
#     'dsaeffect': 'dsanone',
#     'dsaxy': [0.3171, 0.3366],
#     'dsact': 159,
#     'dsaalert': 'dsanone',
#     'dsacolormode': 'dsaxy',
#     'dsamode': 'dsahomeautomation',
#     'dsareachable': True},
#    'dsaswupdate': {'dsastate': 'dsanoupdates',
#     'dsalastinstall': 'dsa2018-01-02T19:24:20'},
#    'dsatype': 'dsaExtended color light',
#    'dsaname': 'dsaHue color lamp 7',
#    'dsamodelid': 'dsaLCT007',
#    'dsamanufacturername': 'dsaPhilips',
#    'dsaproductname': 'dsaHue color lamp',
#    'dsacapabilities': {'dsacertified': True,
#     'dsacontrol': {'dsamindimlevel': 5000,
#      'dsamaxlumen': 600,
#      'dsacolorgamuttype': 'dsaB',
#      'dsacolorgamut': [[0.675, 0.322],
#       [0.675, 0.322],
#       [0.409, 0.518],
#       [0.409, 0.518],
#       [0.167, 0.04],
#       [0.167, 0.04]],
#      'dsact': {'dsamin': 153, 'dsamax': 500}},
#     'dsastreaming': {'dsarenderer': True, 'dsaproxy': False}},
#    'dsaconfig': {'dsaarchetype': 'dsasultanbulb',
#     'dsafunction': 'dsamixed',
#     'dsadirection': 'dsaomnidirectional'},
#    'dsauniqueid': 'dsa00:17:88:01:00:bd:c7:b9-0b',
#    'dsaswversion': 'dsa5.105.0.21169'}},
#  {'1': {'state': {'on': False,
#     'bri': 1,
#     'hue': 33761,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.3171, 0.3366],
#     'ct': 159,
#     'alert': 'none',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2018-01-02T19:24:20'},
#    'type': 'Extended color light',
#    'name': 'Hue color lamp 7',
#    'modelid': 'LCT007',
#    'manufacturername': 'Philips',
#    'productname': 'Hue color lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 5000,
#      'maxlumen': 600,
#      'colorgamuttype': 'B',
#      'colorgamut': [[0.675, 0.322], [0.409, 0.518], [0.167, 0.04]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': False}},
#    'config': {'archetype': 'sultanbulb',
#     'function': 'mixed',
#     'direction': 'omnidirectional'},
#    'uniqueid': '00:17:88:01:00:bd:c7:b9-0b',
#    'swversion': '5.105.0.21169'}},
#  {'dsa7': {'dsaname': 'dsaHue Lamp 7'},
#   'dsa8': {'dsaname': 'dsaHue Lamp 8'},
#   'dsalastscan': 'dsa2012-10-29T12:00:00'},
#  {'7': {'name': 'Hue Lamp 7'},
#   '8': {'name': 'Hue Lamp 8'},
#   'lastscan': '2012-10-29T12:00:00'},
#  {'dsasuccess': {'dsa/lights': 'dsaSearching for new devices'}},
#  {'success': {'/lights': 'Searching for new devices'}},
#  {'dsastate': {'dsahue': 50000,
#    'dsaon': True,
#    'dsaeffect': 'dsanone',
#    'dsaalert': 'dsanone',
#    'dsabri': 200,
#    'dsasat': 200,
#    'dsact': 500,
#    'dsaxy': [0.5, 0.5],
#    'dsareachable': True,
#    'dsacolormode': 'dsahs'},
#   'dsatype': 'dsaLiving Colors',
#   'dsaname': 'dsaLC 1',
#   'dsamodelid': 'dsaLC0015',
#   'dsaswversion': 'dsa1.0.3'},
#  {'state': {'hue': 50000,
#    'on': True,
#    'effect': 'none',
#    'alert': 'none',
#    'bri': 200,
#    'sat': 200,
#    'ct': 500,
#    'xy': [0.5, 0.5],
#    'reachable': True,
#    'colormode': 'hs'},
#   'type': 'Living Colors',
#   'name': 'LC 1',
#   'modelid': 'LC0015',
#   'swversion': '1.0.3'},
#  {'dsahue': 50000, 'dsaon': True, 'dsabri': 200},
#  {'hue': 50000, 'on': True, 'bri': 200},
#  {'dsa1': {'dsaname': 'dsaGroup 1',
#    'dsalights': ['dsa1', 'dsa2'],
#    'dsatype': 'dsaLightGroup',
#    'dsaaction': {'dsaon': True,
#     'dsabri': 254,
#     'dsahue': 10000,
#     'dsasat': 254,
#     'dsaeffect': 'dsanone',
#     'dsaxy': [0.5, 0.5],
#     'dsact': 250,
#     'dsaalert': 'dsaselect',
#     'dsacolormode': 'dsact'}},
#   'dsa2': {'dsaname': 'dsaGroup 2',
#    'dsalights': ['dsa3', 'dsa4', 'dsa5'],
#    'dsatype': 'dsaLightGroup',
#    'dsaaction': {'dsaon': True,
#     'dsabri': 153,
#     'dsahue': 4345,
#     'dsasat': 254,
#     'dsaeffect': 'dsanone',
#     'dsaxy': [0.5, 0.5],
#     'dsact': 250,
#     'dsaalert': 'dsaselect',
#     'dsacolormode': 'dsact'}}},
#  {'1': {'name': 'Group 1',
#    'lights': ['1', '2'],
#    'type': 'LightGroup',
#    'action': {'on': True,
#     'bri': 254,
#     'hue': 10000,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.5, 0.5],
#     'ct': 250,
#     'alert': 'select',
#     'colormode': 'ct'}},
#   '2': {'name': 'Group 2',
#    'lights': ['3', '4', '5'],
#    'type': 'LightGroup',
#    'action': {'on': True,
#     'bri': 153,
#     'hue': 4345,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.5, 0.5],
#     'ct': 250,
#     'alert': 'select',
#     'colormode': 'ct'}}},
#  {'dsalights': ['dsa1', 'dsa2'],
#   'dsaname': 'dsabedroom',
#   'dsatype': 'dsaLightGroup'},
#  {'lights': ['1', '2'], 'name': 'bedroom', 'type': 'LightGroup'},
#  {'dsaaction': {'dsaon': True,
#    'dsahue': 0,
#    'dsaeffect': 'dsanone',
#    'dsabri': 100,
#    'dsasat': 100,
#    'dsact': 500,
#    'dsaxy': [0.5, 0.5]},
#   'dsalights': ['dsa1', 'dsa2'],
#   'dsastate': {'dsaany_on': True, 'dsaall_on': True},
#   'dsatype': 'dsaRoom',
#   'dsaclass': 'dsaBedroom',
#   'dsaname': 'dsaMaster bedroom'},
#  {'action': {'on': True,
#    'hue': 0,
#    'effect': 'none',
#    'bri': 100,
#    'sat': 100,
#    'ct': 500,
#    'xy': [0.5, 0.5]},
#   'lights': ['1', '2'],
#   'state': {'any_on': True, 'all_on': True},
#   'type': 'Room',
#   'class': 'Bedroom',
#   'name': 'Master bedroom'},
#  {'dsaon': True, 'dsahue': 2000, 'dsaeffect': 'dsacolorloop'},
#  {'on': True, 'hue': 2000, 'effect': 'colorloop'},
#  {'dsa1': {'dsaname': 'dsaTimer',
#    'dsadescription': 'dsa',
#    'dsacommand': {'dsaaddress': 'dsa/api/s95jtYH8HUVWNkCO/groups/0/action',
#     'dsabody': {'dsascene': 'dsa02b12e930-off-0'},
#     'dsamethod': 'dsaPUT'},
#    'dsatime': 'dsaPT00:01:00',
#    'dsacreated': 'dsa2014-06-23T13:39:16',
#    'dsastatus': 'dsadisabled',
#    'dsaautodelete': False,
#    'dsastarttime': 'dsa2014-06-23T13:39:16'},
#   'dsa2': {'dsaname': 'dsaAlarm',
#    'dsadescription': 'dsa',
#    'dsacommand': {'dsaaddress': 'dsa/api/s95jtYH8HUVWNkCO/groups/0/action',
#     'dsabody': {'dsascene': 'dsa02b12e930-off-0'},
#     'dsamethod': 'dsaPUT'},
#    'dsalocaltime': 'dsa2014-06-23T19:52:00',
#    'dsatime': 'dsa2014-06-23T13:52:00',
#    'dsacreated': 'dsa2014-06-23T13:38:57',
#    'dsastatus': 'dsadisabled',
#    'dsaautodelete': False}},
#  {'1': {'name': 'Timer',
#    'description': '',
#    'command': {'address': '/api/s95jtYH8HUVWNkCO/groups/0/action',
#     'body': {'scene': '02b12e930-off-0'},
#     'method': 'PUT'},
#    'time': 'PT00:01:00',
#    'created': '2014-06-23T13:39:16',
#    'status': 'disabled',
#    'autodelete': False,
#    'starttime': '2014-06-23T13:39:16'},
#   '2': {'name': 'Alarm',
#    'description': '',
#    'command': {'address': '/api/s95jtYH8HUVWNkCO/groups/0/action',
#     'body': {'scene': '02b12e930-off-0'},
#     'method': 'PUT'},
#    'localtime': '2014-06-23T19:52:00',
#    'time': '2014-06-23T13:52:00',
#    'created': '2014-06-23T13:38:57',
#    'status': 'disabled',
#    'autodelete': False}},
#  {'dsaname': 'dsaWake up',
#   'dsadescription': 'dsaMy wake up alarm',
#   'dsacommand': {'dsaaddress': 'dsa/api/<username>/groups/1/action',
#    'dsamethod': 'dsaPUT',
#    'dsabody': {'dsaon': True}},
#   'dsatime': 'dsaW124/T06:00:00'},
#  {'name': 'Wake up',
#   'description': 'My wake up alarm',
#   'command': {'address': '/api/<username>/groups/1/action',
#    'method': 'PUT',
#    'body': {'on': True}},
#   'time': 'W124/T06:00:00'},
#  {'dsalights': ['dsa3', 'dsa2', 'dsa5'],
#   'dsarecycle': True,
#   'dsaname': 'dsaMy Scene',
#   'dsaappdata': {'dsadata': 'dsaMy App Data', 'dsaversion': 1},
#   'dsapicture': 'dsaABC123DEF456'},
#  {'lights': ['3', '2', '5'],
#   'recycle': True,
#   'name': 'My Scene',
#   'appdata': {'data': 'My App Data', 'version': 1},
#   'picture': 'ABC123DEF456'},
#  {'dsa4e1c6b20e-on-0': {'dsaname': 'dsaKathy on 1449133269486',
#    'dsalights': ['dsa2', 'dsa3'],
#    'dsaowner': 'dsaffffffffe0341b1b376a2389376a2389',
#    'dsarecycle': True,
#    'dsalocked': False,
#    'dsaappdata': {},
#    'dsapicture': 'dsa',
#    'dsalastupdated': 'dsa2015-12-03T08:57:13',
#    'dsaversion': 1},
#   'dsa3T2SvsxvwteNNys': {'dsaname': 'dsaCozy dinner',
#    'dsalights': ['dsa1', 'dsa2'],
#    'dsaowner': 'dsaffffffffe0341b1b376a2389376a2389',
#    'dsarecycle': True,
#    'dsalocked': False,
#    'dsaappdata': {'dsaversion': 1, 'dsadata': 'dsamyAppData'},
#    'dsapicture': 'dsa',
#    'dsalastupdated': 'dsa2015-12-03T10:09:22',
#    'dsaversion': 2}},
#  {'4e1c6b20e-on-0': {'name': 'Kathy on 1449133269486',
#    'lights': ['2', '3'],
#    'owner': 'ffffffffe0341b1b376a2389376a2389',
#    'recycle': True,
#    'locked': False,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2015-12-03T08:57:13',
#    'version': 1},
#   '3T2SvsxvwteNNys': {'name': 'Cozy dinner',
#    'lights': ['1', '2'],
#    'owner': 'ffffffffe0341b1b376a2389376a2389',
#    'recycle': True,
#    'locked': False,
#    'appdata': {'version': 1, 'data': 'myAppData'},
#    'picture': '',
#    'lastupdated': '2015-12-03T10:09:22',
#    'version': 2}},
#  {'dsaname': 'dsaCozy dinner',
#   'dsalights': ['dsa1'],
#   'dsaowner': 'dsanewdeveloper',
#   'dsarecycle': True,
#   'dsalocked': False,
#   'dsaappdata': {},
#   'dsapicture': 'dsa',
#   'dsalastupdated': 'dsa2015-12-03T10:09:22',
#   'dsaversion': 2,
#   'dsalightstates': {'dsa1': {'dsaon': True,
#     'dsabri': 237,
#     'dsaxy': [0.5806, 0.3903]}}},
#  {'name': 'Cozy dinner',
#   'lights': ['1'],
#   'owner': 'newdeveloper',
#   'recycle': True,
#   'locked': False,
#   'appdata': {},
#   'picture': '',
#   'lastupdated': '2015-12-03T10:09:22',
#   'version': 2,
#   'lightstates': {'1': {'on': True, 'bri': 237, 'xy': [0.5806, 0.3903]}}},
#  {'dsa1': {'dsastate': {'dsadaylight': False,
#     'dsalastupdated': 'dsa2014-06-27T07:38:51'},
#    'dsaconfig': {'dsaon': True,
#     'dsalong': 'dsanone',
#     'dsalat': 'dsanone',
#     'dsasunriseoffset': 50,
#     'dsasunsetoffset': 50},
#    'dsaname': 'dsaDaylight',
#    'dsatype': 'dsaDaylight',
#    'dsamodelid': 'dsaPHDL00',
#    'dsamanufacturername': 'dsaPhilips',
#    'dsaswversion': 'dsa1.0'},
#   'dsa2': {'dsastate': {'dsabuttonevent': 0, 'dsalastupdated': 'dsanone'},
#    'dsaconfig': {'dsaon': True},
#    'dsaname': 'dsaTap Switch 2',
#    'dsatype': 'dsaZGPSwitch',
#    'dsamodelid': 'dsaZGPSWITCH',
#    'dsamanufacturername': 'dsaPhilips',
#    'dsauniqueid': 'dsa00:00:00:00:00:40:03:50-f2'}},
#  {'1': {'state': {'daylight': False, 'lastupdated': '2014-06-27T07:38:51'},
#    'config': {'on': True,
#     'long': 'none',
#     'lat': 'none',
#     'sunriseoffset': 50,
#     'sunsetoffset': 50},
#    'name': 'Daylight',
#    'type': 'Daylight',
#    'modelid': 'PHDL00',
#    'manufacturername': 'Philips',
#    'swversion': '1.0'},
#   '2': {'state': {'buttonevent': 0, 'lastupdated': 'none'},
#    'config': {'on': True},
#    'name': 'Tap Switch 2',
#    'type': 'ZGPSwitch',
#    'modelid': 'ZGPSWITCH',
#    'manufacturername': 'Philips',
#    'uniqueid': '00:00:00:00:00:40:03:50-f2'}},
#  {'dsastate': {'dsabuttonevent': 34,
#    'dsalastupdated': 'dsa2013-03-25T13:32:34'},
#   'dsaname': 'dsaWall tap 1',
#   'dsamodelid': 'dsaZGPSWITCH',
#   'dsauniqueid': 'dsa01:23:45:67:89:AB-12',
#   'dsamanufacturername': 'dsaPhilips',
#   'dsaswversion': 'dsa1.0',
#   'dsatype': 'dsaZGPSwitch'},
#  {'state': {'buttonevent': 34, 'lastupdated': '2013-03-25T13:32:34'},
#   'name': 'Wall tap 1',
#   'modelid': 'ZGPSWITCH',
#   'uniqueid': '01:23:45:67:89:AB-12',
#   'manufacturername': 'Philips',
#   'swversion': '1.0',
#   'type': 'ZGPSwitch'},
#  {'dsaname': 'dsaWall Switch Rule',
#   'dsalasttriggered': 'dsa2013-10-17T01:23:20',
#   'dsacreationtime': 'dsa2013-10-10T21:11:45',
#   'dsatimestriggered': 27,
#   'dsaowner': 'dsa78H56B12BA',
#   'dsastatus': 'dsaenabled',
#   'dsaconditions': [{'dsaaddress': 'dsa/sensors/2/state/buttonevent',
#     'dsaoperator': 'dsaeq',
#     'dsavalue': 'dsa16'},
#    {'address': '/sensors/2/state/buttonevent',
#     'operator': 'eq',
#     'value': '16'},
#    {'dsaaddress': 'dsa/sensors/2/state/lastupdated', 'dsaoperator': 'dsadx'},
#    {'address': '/sensors/2/state/lastupdated', 'operator': 'dx'}],
#   'dsaactions': [{'dsaaddress': 'dsa/groups/0/action',
#     'dsamethod': 'dsaPUT',
#     'dsabody': {'dsascene': 'dsaS3'}},
#    {'address': '/groups/0/action', 'method': 'PUT', 'body': {'scene': 'S3'}}]},
#  {'name': 'Wall Switch Rule',
#   'lasttriggered': '2013-10-17T01:23:20',
#   'creationtime': '2013-10-10T21:11:45',
#   'timestriggered': 27,
#   'owner': '78H56B12BA',
#   'status': 'enabled',
#   'conditions': [{'address': '/sensors/2/state/buttonevent',
#     'operator': 'eq',
#     'value': '16'},
#    {'address': '/sensors/2/state/lastupdated', 'operator': 'dx'}],
#   'actions': [{'address': '/groups/0/action',
#     'method': 'PUT',
#     'body': {'scene': 'S3'}}]},
#  {'dsalights': {'dsa1': {'dsastate': {'dsaon': False,
#      'dsabri': 0,
#      'dsahue': 0,
#      'dsasat': 0,
#      'dsaxy': [0.0, 0.0],
#      'dsact': 0,
#      'dsaalert': 'dsanone',
#      'dsaeffect': 'dsanone',
#      'dsacolormode': 'dsahs',
#      'dsareachable': True},
#     'dsatype': 'dsaExtended color light',
#     'dsaname': 'dsaHue Lamp 1',
#     'dsamodelid': 'dsaLCT001',
#     'dsaswversion': 'dsa65003148'},
#    'dsa2': {'dsastate': {'dsaon': True,
#      'dsabri': 254,
#      'dsahue': 33536,
#      'dsasat': 144,
#      'dsaxy': [0.346, 0.3568],
#      'dsact': 201,
#      'dsaalert': 'dsanone',
#      'dsaeffect': 'dsanone',
#      'dsacolormode': 'dsahs',
#      'dsareachable': True},
#     'dsatype': 'dsaExtended color light',
#     'dsaname': 'dsaHue Lamp 2',
#     'dsamodelid': 'dsaLCT001',
#     'dsaswversion': 'dsa65003148'}},
#   'dsagroups': {'dsa1': {'dsaaction': {'dsaon': True,
#      'dsabri': 254,
#      'dsahue': 33536,
#      'dsasat': 144,
#      'dsaxy': [0.346, 0.3568],
#      'dsact': 201,
#      'dsaeffect': 'dsanone',
#      'dsacolormode': 'dsaxy'},
#     'dsalights': ['dsa1', 'dsa2'],
#     'dsaname': 'dsaGroup 1'}},
#   'dsaconfig': {'dsaname': 'dsaPhilips hue',
#    'dsamac': 'dsa00:00:88:00:bb:ee',
#    'dsadhcp': True,
#    'dsaipaddress': 'dsa192.168.1.74',
#    'dsanetmask': 'dsa255.255.255.0',
#    'dsagateway': 'dsa192.168.1.254',
#    'dsaproxyaddress': 'dsa',
#    'dsaproxyport': 0,
#    'dsaUTC': 'dsa2012-10-29T12:00:00',
#    'dsawhitelist': {'dsa1028d66426293e821ecfd9ef1a0731df': {'dsalast use date': 'dsa2012-10-29T12:00:00',
#      'dsacreate date': 'dsa2012-10-29T12:00:00',
#      'dsaname': 'dsatest user'}},
#    'dsaswversion': 'dsa01003372',
#    'dsaswupdate': {'dsaupdatestate': 0,
#     'dsaurl': 'dsa',
#     'dsatext': 'dsa',
#     'dsanotify': False},
#    'dsalinkbutton': False,
#    'dsaportalservices': False},
#   'dsaswupdate2': {'dsacheckforupdate': False,
#    'dsalastchange': 'dsa2017-06-21T19:44:36',
#    'dsabridge': {'dsastate': 'dsanoupdates',
#     'dsalastinstall': 'dsa2017-06-21T19:44:18'},
#    'dsastate': 'dsanoupdates',
#    'dsaautoinstall': {'dsaupdatetime': 'dsaT14:00:00', 'dsaon': False}},
#   'dsaschedules': {'dsa1': {'dsaname': 'dsaschedule',
#     'dsadescription': 'dsa',
#     'dsacommand': {'dsaaddress': 'dsa/api/<username>/groups/0/action',
#      'dsabody': {'dsaon': True},
#      'dsamethod': 'dsaPUT'},
#     'dsatime': 'dsa2012-10-29T12:00:00'}}},
#  {'lights': {'1': {'state': {'on': False,
#      'bri': 0,
#      'hue': 0,
#      'sat': 0,
#      'xy': [0.0, 0.0],
#      'ct': 0,
#      'alert': 'none',
#      'effect': 'none',
#      'colormode': 'hs',
#      'reachable': True},
#     'type': 'Extended color light',
#     'name': 'Hue Lamp 1',
#     'modelid': 'LCT001',
#     'swversion': '65003148'},
#    '2': {'state': {'on': True,
#      'bri': 254,
#      'hue': 33536,
#      'sat': 144,
#      'xy': [0.346, 0.3568],
#      'ct': 201,
#      'alert': 'none',
#      'effect': 'none',
#      'colormode': 'hs',
#      'reachable': True},
#     'type': 'Extended color light',
#     'name': 'Hue Lamp 2',
#     'modelid': 'LCT001',
#     'swversion': '65003148'}},
#   'groups': {'1': {'action': {'on': True,
#      'bri': 254,
#      'hue': 33536,
#      'sat': 144,
#      'xy': [0.346, 0.3568],
#      'ct': 201,
#      'effect': 'none',
#      'colormode': 'xy'},
#     'lights': ['1', '2'],
#     'name': 'Group 1'}},
#   'config': {'name': 'Philips hue',
#    'mac': '00:00:88:00:bb:ee',
#    'dhcp': True,
#    'ipaddress': '192.168.1.74',
#    'netmask': '255.255.255.0',
#    'gateway': '192.168.1.254',
#    'proxyaddress': '',
#    'proxyport': 0,
#    'UTC': '2012-10-29T12:00:00',
#    'whitelist': {'1028d66426293e821ecfd9ef1a0731df': {'last use date': '2012-10-29T12:00:00',
#      'create date': '2012-10-29T12:00:00',
#      'name': 'test user'}},
#    'swversion': '01003372',
#    'swupdate': {'updatestate': 0, 'url': '', 'text': '', 'notify': False},
#    'linkbutton': False,
#    'portalservices': False},
#   'swupdate2': {'checkforupdate': False,
#    'lastchange': '2017-06-21T19:44:36',
#    'bridge': {'state': 'noupdates', 'lastinstall': '2017-06-21T19:44:18'},
#    'state': 'noupdates',
#    'autoinstall': {'updatetime': 'T14:00:00', 'on': False}},
#   'schedules': {'1': {'name': 'schedule',
#     'description': '',
#     'command': {'address': '/api/<username>/groups/0/action',
#      'body': {'on': True},
#      'method': 'PUT'},
#     'time': '2012-10-29T12:00:00'}}}]

# %%
for key, value in new_data[0]['faat'].items():
    print(type(key))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
